# %%
name = "이상아"
age = 27
job = "유니온 기업부설연구소의 연구원"

print(f"제 이름은 '{name}'이고, 나이는 {age}살, 직업은 {job}입니다.")
# Out:
# 제 이름은 '이상아'이고, 나이는 27살, 직업은 유니온 기업부설연구소의 연구원입니다.

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-d4d7ba3e-5701-41b2-b47b-ee1fa97ce054" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4d7ba3e-5701-41b2-b47b-ee1fa97ce054">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls -al
# Out:
# total 2228
# drwxr-xr-x 1 root root    4096 Sep 13 06:22 .
# drwxr-xr-x 1 root root    4096 Sep 13 06:21 ..
# -rw-r--r-- 1 root root 2262080 Sep 13 06:22 ADBE82CC-2827-423F-8700-97641FDE75DF.png
# drwxr-xr-x 4 root root    4096 Sep 11 13:23 .config
# drwxr-xr-x 1 root root    4096 Sep 11 13:23 sample_data
